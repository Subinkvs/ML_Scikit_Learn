# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

# Load dataset (columns: text, label)
df = pd.read_csv("spam.csv")
print(df.to_string())
# Out:
#                                                                   text label
# 0     Free entry in 2 a weekly competition to win FA Cup final tickets  spam
# 1                           Hey, are we still meeting for lunch today?   ham
# 2              Congratulations! You have won a $1000 Walmart gift card  spam
# 3                              Can you send me the report by tomorrow?   ham
# 4   Urgent! Your account has been compromised. Reset your password now  spam
# 5                               Don't forget the team meeting at 10 AM   ham
# 6                              Win a free iPhone by clicking this link  spam
# 7                                 Are you coming to the party tonight?   ham
# 8                      Get cheap medicines online with no prescription  spam
# 9                  Please review the attached document before the call   ham
# 10    Free entry in 2 a weekly competition to win FA Cup final tickets  spam
# 11                          Hey, are we still meeting for lunch today?   ham
# 12             Congratulations! You have won a $1000 Walmart gift card  spam
# 13                             Can you send me the report by tomorrow?   ham
# 14  Urgent! Your account has been compromised. Reset your password now  spam
# 15                              Don't forget the team meeting at 10 AM   ham
# 16                             Win a free iPhone by clicking this link  spam
# 17                                Are you coming to the party tonight?   ham
# 18                     Get cheap medicines online with no prescription  spam
# 19                 Please review the attached document before the call   ham
# 20    Free entry in 2 a weekly competition to win FA Cup final tickets  spam
# 21                          Hey, are we still meeting for lunch today?   ham
# 22             Congratulations! You have won a $1000 Walmart gift card  spam
# 23                             Can you send me the report by tomorrow?   ham
# 24  Urgent! Your account has been compromised. Reset your password now  spam
# 25                              Don't forget the team meeting at 10 AM   ham
# 26                             Win a free iPhone by clicking this link  spam
# 27                                Are you coming to the party tonight?   ham
# 28                     Get cheap medicines online with no prescription  spam
# 29                 Please review the attached document before the call   ham
# 30    Free entry in 2 a weekly competition to win FA Cup final tickets  spam
# 31                          Hey, are we still meeting for lunch today?   ham
# 32             Congratulations! You have won a $1000 Walmart gift card  spam
# 33                             Can you send me the report by tomorrow?   ham
# 34  Urgent! Your account has been compromised. Reset your password now  spam
# 35                              Don't forget the team meeting at 10 AM   ham
# 36                             Win a free iPhone by clicking this link  spam
# 37                                Are you coming to the party tonight?   ham
# 38                     Get cheap medicines online with no prescription  spam
# 39                 Please review the attached document before the call   ham
# 40    Free entry in 2 a weekly competition to win FA Cup final tickets  spam
# 41                          Hey, are we still meeting for lunch today?   ham
# 42             Congratulations! You have won a $1000 Walmart gift card  spam
# 43                             Can you send me the report by tomorrow?   ham
# 44  Urgent! Your account has been compromised. Reset your password now  spam
# 45                              Don't forget the team meeting at 10 AM   ham
# 46                             Win a free iPhone by clicking this link  spam
# 47                                Are you coming to the party tonight?   ham
# 48                     Get cheap medicines online with no prescription  spam
# 49                 Please review the attached document before the call   ham
# 50    Free entry in 2 a weekly competition to win FA Cup final tickets  spam
# 51                          Hey, are we still meeting for lunch today?   ham
# 52             Congratulations! You have won a $1000 Walmart gift card  spam
# 53                             Can you send me the report by tomorrow?   ham
# 54  Urgent! Your account has been compromised. Reset your password now  spam
# 55                              Don't forget the team meeting at 10 AM   ham
# 56                             Win a free iPhone by clicking this link  spam
# 57                                Are you coming to the party tonight?   ham
# 58                     Get cheap medicines online with no prescription  spam
# 59                 Please review the attached document before the call   ham
# 60    Free entry in 2 a weekly competition to win FA Cup final tickets  spam
# 61                          Hey, are we still meeting for lunch today?   ham
# 62             Congratulations! You have won a $1000 Walmart gift card  spam
# 63                             Can you send me the report by tomorrow?   ham
# 64  Urgent! Your account has been compromised. Reset your password now  spam
# 65                              Don't forget the team meeting at 10 AM   ham
# 66                             Win a free iPhone by clicking this link  spam
# 67                                Are you coming to the party tonight?   ham
# 68                     Get cheap medicines online with no prescription  spam
# 69                 Please review the attached document before the call   ham
# 70    Free entry in 2 a weekly competition to win FA Cup final tickets  spam
# 71                          Hey, are we still meeting for lunch today?   ham
# 72             Congratulations! You have won a $1000 Walmart gift card  spam
# 73                             Can you send me the report by tomorrow?   ham
# 74  Urgent! Your account has been compromised. Reset your password now  spam
# 75                              Don't forget the team meeting at 10 AM   ham
# 76                             Win a free iPhone by clicking this link  spam
# 77                                Are you coming to the party tonight?   ham
# 78                     Get cheap medicines online with no prescription  spam
# 79                 Please review the attached document before the call   ham
# 80    Free entry in 2 a weekly competition to win FA Cup final tickets  spam
# 81                          Hey, are we still meeting for lunch today?   ham
# 82             Congratulations! You have won a $1000 Walmart gift card  spam
# 83                             Can you send me the report by tomorrow?   ham
# 84  Urgent! Your account has been compromised. Reset your password now  spam
# 85                              Don't forget the team meeting at 10 AM   ham
# 86                             Win a free iPhone by clicking this link  spam
# 87                                Are you coming to the party tonight?   ham
# 88                     Get cheap medicines online with no prescription  spam
# 89                 Please review the attached document before the call   ham
# 90    Free entry in 2 a weekly competition to win FA Cup final tickets  spam
# 91                          Hey, are we still meeting for lunch today?   ham
# 92             Congratulations! You have won a $1000 Walmart gift card  spam
# 93                             Can you send me the report by tomorrow?   ham
# 94  Urgent! Your account has been compromised. Reset your password now  spam
# 95                              Don't forget the team meeting at 10 AM   ham
# 96                             Win a free iPhone by clicking this link  spam
# 97                                Are you coming to the party tonight?   ham
# 98                     Get cheap medicines online with no prescription  spam
# 99                 Please review the attached document before the call   ham

# %%
df['label'] = df['label'].map({'ham': 0, 'spam': 1})
df

# %%
# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    df['text'], df['label'], test_size=0.2, random_state=42
)

# %%
# TF-IDF vectorization
# Term Frequency – Inverse Document Frequency
vectorizer = TfidfVectorizer(stop_words='english')
X_train_vec = vectorizer.fit_transform(X_train)
X_test_vec = vectorizer.transform(X_test)

# %%
# Train Logistic Regression model
model = LogisticRegression(max_iter=1000)
model.fit(X_train_vec, y_train)

# %%
# Evaluate model
y_pred = model.predict(X_test_vec)
print("Accuracy:", accuracy_score(y_test, y_pred))
# print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 1.0

# %%
# Test with new email
email = ["Free entry in 2 a weekly competition to win FA Cup final tickets"]
email_vec = vectorizer.transform(email)
print("Spam" if model.predict(email_vec)[0] == 1 else "Not Spam")
# Out:
# Spam
